# %%
import pandas as pd
import numpy as np
import math as math
import myplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0be633bfcafc> in <module>
#       2 import numpy as np
#       3 import math as math
# ----> 4 import myplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'myplotlib'

# %%
salary=pd.read_csv('data/StackOverflowDeveloperSurvey.csv',usecols=['Salary'],squeeze=True).dropna()

# %%
salary
# Out:
# 2        113750.000000
# 14       100000.000000
# 17       130000.000000
# 18        82500.000000
# 22       100764.000000
#              ...
# 51371     74193.548387
# 51378    107526.881720
# 51382     32258.064516
# 51387     58000.000000
# 51390     40000.000000
# Name: Salary, Length: 12891, dtype: float64

# %%
salary.head()
# Out:
# 2     113750.0
# 14    100000.0
# 17    130000.0
# 18     82500.0
# 22    100764.0
# Name: Salary, dtype: float64

# %%
len(salary)
# Out:
# 12891

# %%
min(salary)
# Out:
# 0.0

# %%
max(salary)
# Out:
# 197000.0

# %%
list(salary.head(5))
# Out:
# [113750.0, 100000.0, 130000.0, 82500.0, 100764.0]

# %%
dict(salary.head(5))
# Out:
# {2: 113750.0, 14: 100000.0, 17: 130000.0, 18: 82500.0, 22: 100764.0}

# %%
listSalarySorted = sorted(salary,reverse=True)

# %%
listSalarySorted
# Out:
# [197000.0,
#  195000.0,
#  195000.0,
#  195000.0,
#  195000.0,
#  195000.0,
#  194000.0,
#  193750.0,
#  193000.0,
#  192000.0,
#  192000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  188000.0,
#  187500.0,
#  187200.0,
#  187000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  184000.0,
#  182000.0,
#  181818.181818182,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  178000.0,
#  178000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  174242.424242424,
#  174000.0,
#  174000.0,
#  173716.668114306,
#  173300.0,
#  173000.0,
#  173000.0,
#  173000.0,
#  172300.0,
#  172043.010752688,
#  172000.0,
#  172000.0,
#  172000.0,
#  172000.0,
#  172000.0,
#  171000.0,
#  170940.170940171,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  168750.0,
#  168000.0,
#  168000.0,
#  168000.0,
#  168000.0,
#  168000.0,
#  167000.0,
#  166500.0,
#  166000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  164000.0,
#  163134.796652474,
#  163000.0,
#  163000.0,
#  162000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  159120.0,
#  159000.0,
#  158100.0,
#  158000.0,
#  158000.0,
#  157000.0,
#  157000.0,
#  157000.0,
#  157000.0,
#  157000.0,
#  156250.0,
#  156250.0,
#  156250.0,
#  156000.0,
#  156000.0,
#  156000.0,
#  156000.0,
#  156000.0,
#  156000.0,
#  156000.0,
#  156000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  154000.0,
#  153000.0,
#  153000.0,
#  153000.0,
#  153000.0,
#  153000.0,
#  153000.0,
#  153000.0,
#  153000.0,
#  153000.0,
#  152900.0,
#  152000.0,
#  152000.0,
#  151515.151515152,
#  151515.151515152,
#  151000.0,
#  150537.634408602,
#  150500.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  149000.0,
#  149000.0,
#  149000.0,
#  148000.0,
#  148000.0,
#  148000.0,
#  148000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  146600.0,
#  146000.0,
#  146000.0,
#  146000.0,
#  146000.0,
#  146000.0,
#  145600.0,
#  145600.0,
#  145600.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  144550.0,
#  144086.021505376,
#  144000.0,
#  144000.0,
#  144000.0,
#  144000.0,
#  144000.0,
#  144000.0,
#  143820.0,
#  143750.0,
#  143750.0,
#  143750.0,
#  143750.0,
#  143540.669856459,
#  143181.818181818,
#  143000.0,
#  143000.0,
#  143000.0,
#  143000.0,
#  143000.0,
#  143000.0,
#  143000.0,
#  143000.0,
#  142500.0,
#  142500.0,
#  142000.0,
#  142000.0,
#  142000.0,
#  142000.0,
#  142000.0,
#  142000.0,
#  142000.0,
#  141000.0,
#  141000.0,
#  141000.0,
#  141000.0,
#  141000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  139939.0,
#  139784.946236559,
#  139784.946236559,
#  139784.946236559,
#  139171.974522293,
#  139000.0,
#  139000.0,
#  139000.0,
#  139000.0,
#  139000.0,
#  138500.0,
#  138004.0,
#  138000.0,
#  138000.0,
#  138000.0,
#  138000.0,
#  138000.0,
#  138000.0,
#  137634.408602151,
#  137500.0,
#  137500.0,
#  137500.0,
#  137500.0,
#  137500.0,
#  137500.0,
#  137000.0,
#  137000.0,
#  137000.0,
#  136500.0,
#  136363.636363636,
#  136200.0,
#  136000.0,
#  136000.0,
#  136000.0,
#  136000.0,
#  136000.0,
#  136000.0,
#  136000.0,
#  136000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  134803.225806452,
#  134770.889487871,
#  134408.602150538,
#  134000.0,
#  134000.0,
#  134000.0,
#  134000.0,
#  134000.0,
#  134000.0,
#  134000.0,
#  134000.0,
#  133125.0,
#  133125.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  132575.757575758,
#  132478.632478632,
#  132392.0,
#  132000.0,
#  132000.0,
#  132000.0,
#  132000.0,
#  132000.0,
#  132000.0,
#  132000.0,
#  132000.0,
#  131250.0,
#  131250.0,
#  131250.0,
#  131250.0,
#  131250.0,
#  131000.0,
#  131000.0,
#  131000.0,
#  131000.0,
#  131000.0,
#  130997.30458221,
#  130839.083557951,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  129380.053908356,
#  129032.258064516,
#  129032.258064516,
#  129032.258064516,
#  129032.258064516,
#  129000.0,
#  129000.0,
#  129000.0,
#  129000.0,
#  129000.0,
#  129000.0,
#  129000.0,
#  129000.0,
#  129000.0,
#  128787.878787879,
#  128750.0,
#  128571.428571429,
#  128500.0,
#  128000.0,
#  128000.0,
#  128000.0,
#  128000.0,
#  128000.0,
#  128000.0,
#  128000.0,
#  128000.0,
#  127834.0,
#  127500.0,
#  127500.0,
#  127262.443438914,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  126680.0,
#  126500.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  125806.451612903,
#  125757.575757576,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  124800.0,
#  124400.0,
#  124000.0,
#  124000.0,
#  124000.0,
#  124000.0,
#  124000.0,
#  124000.0,
#  124000.0,
#  124000.0,
#  124000.0,
#  123989.218328841,
#  123655.913978495,
#  123500.0,
#  123456.790123457,
#  123456.0,
#  123000.0,
#  123000.0,
#  123000.0,
#  123000.0,
#  123000.0,
#  123000.0,
#  122500.0,
#  122500.0,
#  122500.0,
#  122400.0,
#  122088.0,
#  122000.0,
#  122000.0,
#  122000.0,
#  122000.0,
#  122000.0,
#  121900.0,
#  121500.0,
#  121250.0,
#  121212.121212121,
#  121212.121212121,
#  121212.121212121,
#  121043.0,
#  121000.0,
#  121000.0,
#  121000.0,
#  121000.0,
#  121000.0,
#  121000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  ...]

# %%
listSalarySorted[:5]
# Out:
# [197000.0, 195000.0, 195000.0, 195000.0, 195000.0]

# %%
salary.name = 'Salary of a aperson'

# %%
salary.head()
# Out:
# 2     113750.0
# 14    100000.0
# 17    130000.0
# 18     82500.0
# 22    100764.0
# Name: Salary of a aperson, dtype: float64
