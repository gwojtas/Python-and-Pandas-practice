# %%
import numpy as np
import pandas as pd

# %%
url ='https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?file=data/isoc_cimobi_frq.tsv.gz&unzip=true'

# %%
df=pd.read_csv(url, delimiter = '\t')

# %%
df.head()
# Out:
#        indic_is,ind_type,unit,time\geo EU27_2020  EU28  EU27_2007  EU15   EA   \
# 0       I_IHDDAY,CB_EU_FOR,PC_IND,2012        13    15         15    16   12
# 1   I_IHDDAY,CB_EU_FOR,PC_IND_IU3,2012        18    21         21    21   17
# 2  I_IHDDAY,CB_EU_FOR,PC_IND_IUHD,2012        57    57         57    57   55
# 3       I_IHDDAY,CB_EXT_EU,PC_IND,2012        15    21         21    22   13
# 4   I_IHDDAY,CB_EXT_EU,PC_IND_IU3,2012        21    28         28    29   19
#
#    BE    BG   CZ    DK   ...  SI    SK    FI    SE    IS    NO    UK  ME  MK   \
# 0  15    : u  : u   22   ...  : u  14 u  35 u  35 u   16   31 u   39   :   :
# 1  19    : u  : u   22   ...  : u  17 u  36 u  40 u   17   32 u  46 u  :   :
# 2  48    : u  : u  49 u  ...  : u   : u   : u   : u  40 u  50 u  60 u  :   :
# 3  11   25 u   :    35   ...   3    : u   22    39   16 u  32 u   39   :   :
# 4  15   28 u   :    39   ...   5    : u  24 u   42   17 u  32 u   43   :   :
#
#   TR
# 0  :
# 1  :
# 2  :
# 3  :
# ...

# %%
df_desc=df['indic_is,ind_type,unit,time\\geo'].str.split(',', expand=True)

# %%
df_desc.rename({0:'indic_is',1:'ind_type',2:'unit',3:'time'},axis=1, inplace=True)

# %%
df_desc.join(df)
# Out:
#       indic_is   ind_type         unit  time  \
# 0     I_IHDDAY  CB_EU_FOR       PC_IND  2012
# 1     I_IHDDAY  CB_EU_FOR   PC_IND_IU3  2012
# 2     I_IHDDAY  CB_EU_FOR  PC_IND_IUHD  2012
# 3     I_IHDDAY  CB_EXT_EU       PC_IND  2012
# 4     I_IHDDAY  CB_EXT_EU   PC_IND_IU3  2012
# ..         ...        ...          ...   ...
# 442  I_IHDLTWK    Y75_MAX   PC_IND_IU3  2012
# 443  I_IHDLTWK    Y75_MAX  PC_IND_IUHD  2012
# 444   I_IHDUSE  CB_EU_FOR       PC_IND  2012
# 445   I_IHDUSE  CB_EU_FOR   PC_IND_IU3  2012
# 446   I_IHDUSE  CB_EU_FOR  PC_IND_IUHD  2012
#
#          indic_is,ind_type,unit,time\geo EU27_2020  EU28  EU27_2007  EU15   \
# 0         I_IHDDAY,CB_EU_FOR,PC_IND,2012        13    15         15    16
# 1     I_IHDDAY,CB_EU_FOR,PC_IND_IU3,2012        18    21         21    21
# 2    I_IHDDAY,CB_EU_FOR,PC_IND_IUHD,2012        57    57         57    57
# 3         I_IHDDAY,CB_EXT_EU,PC_IND,2012        15    21         21    22
# ...

# %%
df_desc.drop('indic_is,ind_type,unit,time\\geo', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18648/940071495.py in <module>
# ----> 1 df_desc.drop('indic_is,ind_type,unit,time\\geo', axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
plik_json = 'https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?file=data/isoc_cimobi_frq.tsv.gz&unzip=true'

# %%
pd.read_json(plik_json)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18648/3862471635.py in <module>
# ----> 1 pd.read_json(plik_json)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
