# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
education = pd.read_csv("data/StackOverflowDeveloperSurvey.csv",usecols=['FormalEducation'])

# %%
education
# Out:
#                                          FormalEducation
# 0                                       Secondary school
# 1      Some college/university study without earning ...
# 2                                      Bachelor's degree
# 3                                        Doctoral degree
# 4                                        Master's degree
# ...                                                  ...
# 51387                                  Bachelor's degree
# 51388                                    Master's degree
# 51389  Some college/university study without earning ...
# 51390                                  Bachelor's degree
# 51391                                  Bachelor's degree
#
# [51392 rows x 1 columns]

# %%
type(education)
# Out:
# pandas.core.frame.DataFrame

# %%
education.head()
# Out:
#                                      FormalEducation
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree

# %%
education.tail()
# Out:
#                                          FormalEducation
# 51387                                  Bachelor's degree
# 51388                                    Master's degree
# 51389  Some college/university study without earning ...
# 51390                                  Bachelor's degree
# 51391                                  Bachelor's degree

# %%
allinfo=pd.read_csv("data/StackOverflowDeveloperSurvey.csv")

# %%
allinfo
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# ...           ...                                                ...
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
#                     ProgramHobby         Country      University  \
# 0                      Yes, both   United States              No
# ...

# %%
type(allinfo)
# Out:
# pandas.core.frame.DataFrame

# %%
country=allinfo["Country"]

# %%
country.head()
# Out:
# 0     United States
# 1    United Kingdom
# 2    United Kingdom
# 3     United States
# 4       Switzerland
# Name: Country, dtype: object

# %%
filterOnlyUSA = country=="United States"

# %%
filterOnlyUSA.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Country, dtype: bool

# %%
education.where(filterOnlyUSA).dropna().head(10)
# Out:
#               FormalEducation
# 0            Secondary school
# 3             Doctoral degree
# 6             Master's degree
# 10          Bachelor's degree
# 15  Primary/elementary school
# 17          Bachelor's degree
# 18          Bachelor's degree
# 25            Master's degree
# 27          Bachelor's degree
# 29          Bachelor's degree

# %%
x= education.head(10)

# %%
x
# Out:
#                                      FormalEducation
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
# 5                                   Secondary school
# 6                                    Master's degree
# 7                                    Master's degree
# 8                                  Bachelor's degree
# 9                                    Master's degree

# %%
suppliers = pd.read_csv("data/suppliers_del_1.csv",usecols=['SupplierID','CompanyName','City'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10744/829683116.py in <module>
# ----> 1 suppliers = pd.read_csv("data/suppliers_del_1.csv",usecols=['SupplierID','CompanyName','City'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
