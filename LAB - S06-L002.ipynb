# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import time

# %%
products = pd.read_csv('data/Wa_Sales_Products_2012-14.csv')

# %%
products.head()
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
# 1    United States               Fax  Outdoors Shop  Camping Equipment
# 2    United States               Fax  Outdoors Shop  Camping Equipment
# 3    United States               Fax  Outdoors Shop  Camping Equipment
# 4    United States               Fax  Outdoors Shop  Camping Equipment
#
#     Product type                    Product  Year  Quarter    Revenue  \
# 0   Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1   Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2          Tents                  Star Dome  2012  Q1 2012   89940.48
# 3          Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4  Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
#
#    Quantity  Gross margin
# 0       489      0.347548
# 1       252      0.474274
# 2       147      0.352772
# ...

# %%
groups = products.groupby(by=['Retailer country', 'Quarter'])

# %%
groups.mean().head(20)
# Out:
#                             Year       Revenue    Quantity  Gross margin
# Retailer country Quarter
# Australia        Q1 2012  2012.0  18906.876142  403.845697      0.446321
#                  Q1 2013  2013.0  30539.494720  559.519174      0.456356
#                  Q1 2014  2014.0  41729.307912  756.250000      0.445961
#                  Q2 2012  2012.0  16895.175467  344.487252      0.446051
#                  Q2 2013  2013.0  37051.540029  648.576812      0.453804
#                  Q2 2014  2014.0  46304.001311  816.393293      0.447167
#                  Q3 2012  2012.0  17504.806761  340.140845      0.448517
#                  Q3 2013  2013.0  34052.142800  579.376000      0.461012
#                  Q3 2014  2014.0  28287.220462  491.246154      0.446856
#                  Q4 2012  2012.0  19768.131373  402.621849      0.450948
#                  Q4 2013  2013.0  37522.124826  659.457413      0.457902
# ...

# %%
groups.sum().head(20)
# Out:
#                             Year      Revenue  Quantity  Gross margin
# Retailer country Quarter
# Australia        Q1 2012  678044   6371617.26    136096    149.964018
#                  Q1 2013  682407  10352888.71    189677    151.053868
#                  Q1 2014  733096  15189468.08    275275    157.870105
#                  Q2 2012  710236   5963996.94    121604    157.009965
#                  Q2 2013  694485  12782781.31    223759    156.562335
#                  Q2 2014  660592  15187712.43    267777    145.329274
#                  Q3 2012  714260   6214206.40    120750    158.775061
#                  Q3 2013  754875  12769553.55    217266    172.879428
#                  Q3 2014  392730   5516007.99     95793     87.136922
#                  Q4 2012  718284   7057222.90    143736    160.086380
#                  Q4 2013  638121  11894513.57    209048    145.155059
# Austria          Q1 2012  696152   8788978.08    186218    153.779082
# ...

# %%
groups.count().head(20)
# Out:
#                           Order method type  Retailer type  Product line  \
# Retailer country Quarter
# Australia        Q1 2012                337            337           337
#                  Q1 2013                339            339           339
#                  Q1 2014                364            364           364
#                  Q2 2012                353            353           353
#                  Q2 2013                345            345           345
#                  Q2 2014                328            328           328
#                  Q3 2012                355            355           355
#                  Q3 2013                375            375           375
#                  Q3 2014                195            195           195
#                  Q4 2012                357            357           357
#                  Q4 2013                317            317           317
# ...

# %%
groups.min().head(20)
# Out:
#                          Order method type     Retailer type  \
# Retailer country Quarter
# Australia        Q1 2012            E-mail  Department Store
#                  Q1 2013       Sales visit  Department Store
#                  Q1 2014       Sales visit  Department Store
#                  Q2 2012              Mail  Department Store
#                  Q2 2013            E-mail  Department Store
#                  Q2 2014       Sales visit  Department Store
#                  Q3 2012       Sales visit  Department Store
#                  Q3 2013       Sales visit  Department Store
#                  Q3 2014       Sales visit  Department Store
#                  Q4 2012       Sales visit  Department Store
#                  Q4 2013       Sales visit  Department Store
# Austria          Q1 2012       Sales visit  Department Store
#                  Q1 2013       Sales visit  Department Store
#                  Q1 2014       Sales visit  Department Store
# ...

# %%
groups.max().head(20)
# Out:
#                          Order method type    Retailer type  \
# Retailer country Quarter
# Australia        Q1 2012               Web  Warehouse Store
#                  Q1 2013               Web  Warehouse Store
#                  Q1 2014               Web  Warehouse Store
#                  Q2 2012               Web  Warehouse Store
#                  Q2 2013               Web  Warehouse Store
#                  Q2 2014               Web  Warehouse Store
#                  Q3 2012               Web  Warehouse Store
#                  Q3 2013               Web  Warehouse Store
#                  Q3 2014               Web  Warehouse Store
#                  Q4 2012               Web  Warehouse Store
#                  Q4 2013               Web  Warehouse Store
# Austria          Q1 2012               Web  Warehouse Store
#                  Q1 2013               Web  Warehouse Store
#                  Q1 2014               Web  Warehouse Store
# ...

# %%
 funkx = ["sum","min","max"]
    
groups.agg({"Revenue": funkx,
             "Quantity": funkx,
             "Gross margin" :"mean"}).head()
# Out:
#                               Revenue                   Quantity             \
#                                   sum    min        max      sum min    max
# Retailer country Quarter
# Australia        Q1 2012   6371617.26    0.0  166079.98   136096   4   6083
#                  Q1 2013  10352888.71    0.0  272857.12   189677  11   9442
#                  Q1 2014  15189468.08    0.0  516135.14   275275  22  20031
#                  Q2 2012   5963996.94    0.0  195361.79   121604   6   3222
#                  Q2 2013  12782781.31  294.0  420537.25   223759  18   6280
#
#                          Gross margin
#                                  mean
# Retailer country Quarter
# Australia        Q1 2012     0.446321
#                  Q1 2013     0.456356
#                  Q1 2014     0.445961
#                  Q2 2012     0.446051
#                  Q2 2013     0.453804
