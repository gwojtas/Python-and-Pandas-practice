# %%
import pandas as pd
import numpy as np
fuel = pd.read_csv("data/fuel.csv",
usecols=['Vehicle ID','Year','Make',
'Model','Class','Fuel Type',
'Combined MPG (FT1)','Start Stop Technology'],
index_col = 'Vehicle ID', low_memory=False)
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1) Start Stop Technology
# Vehicle ID
# 26587        Regular                20.0                   NaN
# 27705        Regular                20.0                   NaN
# 26561        Regular                21.0                   NaN
# 27681        Regular                21.0                   NaN
# 27550        Regular                17.0                   NaN

# %%
listOfCars=['Renault','Toyota','Ford']

# %%
isInList = fuel['Make'].isin(listOfCars)

# %%
isInList
# Out:
# Vehicle ID
# 26587    False
# 27705    False
# 26561    False
# 27681    False
# 27550    False
#          ...
# 32060    False
# 32063    False
# 32065    False
# 32064    False
# 32106    False
# Name: Make, Length: 31684, dtype: bool

# %%
fuel[isInList]
# Out:
#             Year  Make                      Model  \
# Vehicle ID
# 27613       1984  Ford                 Bronco 4WD
# 27616       1984  Ford                 Bronco 4WD
# 27619       1984  Ford                 Bronco 4WD
# 27622       1984  Ford                 Bronco 4WD
# 28472       1984  Ford                 Bronco 4WD
# ...          ...   ...                        ...
# 31786       2012  Ford                 Taurus AWD
# 31784       2012  Ford                 Taurus FWD
# 31785       2012  Ford                 Taurus FWD
# 31458       2012  Ford        Transit Connect Van
# 31460       2012  Ford  Transit Connect Wagon FWD
#
#                                   Class Fuel Type  Combined MPG (FT1)  \
# Vehicle ID
# 27613       Special Purpose Vehicle 4WD   Regular                13.0
# 27616       Special Purpose Vehicle 4WD   Regular                11.0
# 27619       Special Purpose Vehicle 4WD   Regular                10.0
# 27622       Special Purpose Vehicle 4WD   Regular                11.0
# 28472       Special Purpose Vehicle 4WD   Regular                13.0
# ...                                 ...       ...                 ...
# 31786                        Large Cars   Regular                20.0
# 31784                        Large Cars   Regular                21.0
# 31785                        Large Cars   Regular                22.0
# 31458       Special Purpose Vehicle 2WD   Regular                23.0
# 31460       Special Purpose Vehicle 2WD   Regular                23.0
#
#            Start Stop Technology
# Vehicle ID
# 27613                        NaN
# 27616                        NaN
# 27619                        NaN
# 27622                        NaN
# 28472                        NaN
# ...                          ...
# 31786                        NaN
# 31784                        NaN
# 31785                        NaN
# 31458                        NaN
# 31460                        NaN
#
# [4376 rows x 7 columns]

# %%
isNoStartStopDefined  = fuel['Start Stop Technology'].isnull()

# %%
isNoStartStopDefined
# Out:
# Vehicle ID
# 26587    True
# 27705    True
# 26561    True
# 27681    True
# 27550    True
# 28426    True
# 27549    True
# 28425    True
# 27593    True
# 28455    True
# 27591    True
# 27594    True
# 28454    True
# 28456    True
# 27592    True
# 27595    True
# 28457    True
# 27585    True
# 27588    True
# 28449    True
# Name: Start Stop Technology, dtype: bool

# %%
fuel[isNoStartStopDefined]
# Out:
# <ipython-input-13-914c30c0ad94>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fuel[isNoStartStopDefined]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-13-914c30c0ad94> in <module>
# ----> 1 fuel[isNoStartStopDefined]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3066         # check_bool_indexer will throw exception if Series key cannot
#    3067         # be reindexed to match DataFrame rows
# -> 3068         key = check_bool_indexer(self.index, key)
#    3069         indexer = key.nonzero()[0]
#    3070         return self._take_with_is_copy(indexer, axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2267         mask = isna(result._values)
#    2268         if mask.any():
# -> 2269             raise IndexingError(
#    2270                 "Unalignable boolean Series provided as "
#    2271                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
